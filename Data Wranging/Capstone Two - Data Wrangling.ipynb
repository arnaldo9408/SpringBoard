# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#First we import all the csv files we need for the work and make a quick look at them
df_features = pd.read_csv('features.csv')
df_sample = pd.read_csv('sampleSubmission.csv')
df_stores = pd.read_csv('stores.csv')
df_test = pd.read_csv('test.csv')
df_train = pd.read_csv('train.csv')
df_stock_price = pd.read_csv('WMT.csv')

# %% [markdown]
# # First 5 rows,types of the columns and information of the null values for each of the data imported

# %% [markdown]
# ### Features

# %%
#Head for features
df_features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN        NaN  211.350143         8.106      False

# %%
df_features.tail()
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5  CPI  Unemployment  IsHoliday
# 8185       3.00    2449.97    3169.69  NaN           NaN      False
# 8186     582.74    5797.47    1514.93  NaN           NaN      False
# 8187      85.72     744.84    2150.36  NaN           NaN      False
# 8188     204.19     363.00    1059.46  NaN           NaN      False
# 8189       2.06      10.88    1864.57  NaN           NaN      False

# %%
df_features.dtypes
# Out:
# Store             int64
# Date             object
# Temperature     float64
# Fuel_Price      float64
# MarkDown1       float64
# MarkDown2       float64
# MarkDown3       float64
# MarkDown4       float64
# MarkDown5       float64
# CPI             float64
# Unemployment    float64
# IsHoliday          bool
# dtype: object

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
# Store           8190 non-null int64
# Date            8190 non-null object
# Temperature     8190 non-null float64
# Fuel_Price      8190 non-null float64
# MarkDown1       4032 non-null float64
# MarkDown2       2921 non-null float64
# MarkDown3       3613 non-null float64
# MarkDown4       3464 non-null float64
# MarkDown5       4050 non-null float64
# CPI             7605 non-null float64
# Unemployment    7605 non-null float64
# IsHoliday       8190 non-null bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB

# %% [markdown]
# ## Sample

# %%
df_sample.head()
# Out:
#                Id  Weekly_Sales
# 0  1_1_2012-11-02             0
# 1  1_1_2012-11-09             0
# 2  1_1_2012-11-16             0
# 3  1_1_2012-11-23             0
# 4  1_1_2012-11-30             0

# %%
df_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 2 columns):
# Id              115064 non-null object
# Weekly_Sales    115064 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 1.8+ MB

# %%
df_sample.dtypes
# Out:
# Id              object
# Weekly_Sales     int64
# dtype: object

# %% [markdown]
# ## Stores

# %%
df_stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
df_stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
# Store    45 non-null int64
# Type     45 non-null object
# Size     45 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB

# %%
df_stores.dtypes
# Out:
# Store     int64
# Type     object
# Size      int64
# dtype: object

# %% [markdown]
# ## Test

# %%
df_test.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 4 columns):
# Store        115064 non-null int64
# Dept         115064 non-null int64
# Date         115064 non-null object
# IsHoliday    115064 non-null bool
# dtypes: bool(1), int64(2), object(1)
# memory usage: 2.7+ MB

# %%
df_test.dtypes
# Out:
# Store         int64
# Dept          int64
# Date         object
# IsHoliday      bool
# dtype: object

# %% [markdown]
# ## Train

# %%
df_train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
df_train_grouped = df_train.groupby(['Date', 'Dept', 'Store']).agg('sum')

# %%
df_train_grouped
# Out:
#                        Weekly_Sales  IsHoliday
# Date       Dept Store
# 2010-02-05 1    1          24924.50      False
#                 2          35034.06      False
#                 3           6453.58      False
#                 4          38724.42      False
#                 5           9323.89      False
# ...                             ...        ...
# 2012-10-26 98   44          4348.96      False
#                 45          1076.80      False
#            99   8              0.01      False
#                 32            12.00      False
#                 41            29.88      False
#
# [421570 rows x 2 columns]

# %%
df_train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
df_train.shape
# Out:
# (421570, 5)

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Date            421570 non-null object
# Weekly_Sales    421570 non-null float64
# IsHoliday       421570 non-null bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %%
df_train.dtypes
# Out:
# Store             int64
# Dept              int64
# Date             object
# Weekly_Sales    float64
# IsHoliday          bool
# dtype: object

# %% [markdown]
# ## Stock Price

# %%
df_stock_price.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0  2010-02-05  52.770000  53.529999  52.759998  53.450001  41.123001  15545800
# 1  2010-02-08  53.380001  53.540001  52.919998  52.930000  40.722912  10505900
# 2  2010-02-09  53.209999  53.619999  52.820000  53.250000  40.969128  10825000
# 3  2010-02-10  53.270000  53.500000  52.959999  53.240002  40.961433   9408400
# 4  2010-02-11  53.130001  53.450001  52.910000  53.080002  40.838329  11579600

# %%
df_stock_price = df_stock_price[['Date', 'Close']]

# %%
df_stock_price.head()
# Out:
#          Date      Close
# 0  2010-02-05  53.450001
# 1  2010-02-08  52.930000
# 2  2010-02-09  53.250000
# 3  2010-02-10  53.240002
# 4  2010-02-11  53.080002

# %%
df_stock_price.dtypes
# Out:
# Date      object
# Close    float64
# dtype: object

# %% [markdown]
# # Convert all the date's columns to datetime for future use

# %%
df_features['Date'] =  pd.to_datetime(df_features['Date'])
df_train['Date'] = pd.to_datetime(df_train['Date'])
df_test['Date'] = pd.to_datetime(df_test['Date'])
df_stock_price['Date'] = pd.to_datetime(df_stock_price['Date'])

# %% [markdown]
# # Start the merging of all the data frames to have all the information in one big data frame

# %% [markdown]
# #### By looking the data, we are taking off two data frames since there is no concordance with the dates of the other data frames. Columns we are disregarding are test and store

# %%
'''We start merging the features data frame with the train dataframe. Left Join to include values, and on the date, store and Is Holiday 
column as the concordance column between the two data frames'''
df_features_train = pd.merge(df_train, df_features,how = 'inner', on = ['Date', 'Store', 'IsHoliday'])

# %%
df_features_train.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50      False        42.31       2.572
# 1      1     2 2010-02-05      50605.27      False        42.31       2.572
# 2      1     3 2010-02-05      13740.12      False        42.31       2.572
# 3      1     4 2010-02-05      39954.04      False        42.31       2.572
# 4      1     5 2010-02-05      32229.38      False        42.31       2.572
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.096358
# 2        NaN        NaN        NaN        NaN        NaN  211.096358
# 3        NaN        NaN        NaN        NaN        NaN  211.096358
# 4        NaN        NaN        NaN        NaN        NaN  211.096358
#
#    Unemployment
# 0         8.106
# 1         8.106
# 2         8.106
# 3         8.106
# ...

# %%
df_features_train.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50      False        42.31       2.572
# 1      1     2 2010-02-05      50605.27      False        42.31       2.572
# 2      1     3 2010-02-05      13740.12      False        42.31       2.572
# 3      1     4 2010-02-05      39954.04      False        42.31       2.572
# 4      1     5 2010-02-05      32229.38      False        42.31       2.572
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.096358
# 2        NaN        NaN        NaN        NaN        NaN  211.096358
# 3        NaN        NaN        NaN        NaN        NaN  211.096358
# 4        NaN        NaN        NaN        NaN        NaN  211.096358
#
#    Unemployment
# 0         8.106
# 1         8.106
# 2         8.106
# 3         8.106
# ...

# %%
'''We continued merging the df_walmart data frame with the stock price dataframe. Left Join to include values and the
date column  as the concordance column between the two data frames'''
df_features_train_stock = pd.merge(df_features_train, df_stock_price,how = 'inner', on = ['Date'])

# %%
#See the new dataframe 
df_features_train_stock.head()
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50      False        42.31       2.572
# 1      1     2 2010-02-05      50605.27      False        42.31       2.572
# 2      1     3 2010-02-05      13740.12      False        42.31       2.572
# 3      1     4 2010-02-05      39954.04      False        42.31       2.572
# 4      1     5 2010-02-05      32229.38      False        42.31       2.572
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.096358
# 2        NaN        NaN        NaN        NaN        NaN  211.096358
# 3        NaN        NaN        NaN        NaN        NaN  211.096358
# 4        NaN        NaN        NaN        NaN        NaN  211.096358
#
#    Unemployment      Close
# 0         8.106  53.450001
# 1         8.106  53.450001
# ...

# %%
#See the data frame types to confirm all is in order
df_features_train_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 409727 entries, 0 to 409726
# Data columns (total 15 columns):
# Store           409727 non-null int64
# Dept            409727 non-null int64
# Date            409727 non-null datetime64[ns]
# Weekly_Sales    409727 non-null float64
# IsHoliday       409727 non-null bool
# Temperature     409727 non-null float64
# Fuel_Price      409727 non-null float64
# MarkDown1       147698 non-null float64
# MarkDown2       111033 non-null float64
# MarkDown3       134202 non-null float64
# MarkDown4       132337 non-null float64
# MarkDown5       148449 non-null float64
# CPI             409727 non-null float64
# Unemployment    409727 non-null float64
# Close           409727 non-null float64
# dtypes: bool(1), datetime64[ns](1), float64(11), int64(2)
# memory usage: 47.3 MB

# %%
#Percentage of NaN values for each column
print('The percentage of NaN values is', 270892/423325)
print('The percentage of NaN values is', 310793/423325)
print('The percentage of NaN values is', 284667/423325)
print('The percentage of NaN values is', 286859/423325)
print('The percentage of NaN values is', 270138/423325)
# Out:
# The percentage of NaN values is 0.6399149589558849
# The percentage of NaN values is 0.7341711451012816
# The percentage of NaN values is 0.6724549695860155
# The percentage of NaN values is 0.6776330242721313
# The percentage of NaN values is 0.6381338215319199

# %% [markdown]
# # Fill of the NaN Values

# %%
'''Replace the NaN Values
Close price: It should have been a weekend day where the stock is not traded. Replace NaN values with the value
of the days before
Unemployment: Replace this value with the mean
Weekly Sales
CPI: Fill NaN values with the mean
Weekly_Sales = Fill NaN values with the mean
Store_y, Dept_y, Store, and Dept_x can be deleted from the data Frame
Markdown : Delete columns since the percentage of NaN values is too high
'''
# Out:
# 'Replace the NaN Values\nClose price: It should have been a weekend day where the stock is not traded. Replace NaN values with the value\nof the days before\nUnemployment: Replace this value with the mean\nWeekly Sales\nCPI: Fill NaN values with the mean\nWeekly_Sales = Fill NaN values with the mean\nStore_y, Dept_y, Store, and Dept_x can be deleted from the data Frame\nMarkdown : Delete columns since the percentage of NaN values is too high\n'

# %%
df_features_train_stock.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Temperature',
#        'Fuel_Price', 'MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4',
#        'MarkDown5', 'CPI', 'Unemployment', 'Close'],
#       dtype='object')

# %%
#Extract columns I am interested of the data frame
df_features_train_stock = df_features_train_stock[['Date','Temperature','Fuel_Price', 'CPI', 'Unemployment', 'IsHoliday', 'Weekly_Sales',
                              'Close', 'Dept']]

# %%
df_features_train_stock.head()
# Out:
#         Date  Temperature  Fuel_Price         CPI  Unemployment  IsHoliday  \
# 0 2010-02-05        42.31       2.572  211.096358         8.106      False
# 1 2010-02-05        42.31       2.572  211.096358         8.106      False
# 2 2010-02-05        42.31       2.572  211.096358         8.106      False
# 3 2010-02-05        42.31       2.572  211.096358         8.106      False
# 4 2010-02-05        42.31       2.572  211.096358         8.106      False
#
#    Weekly_Sales      Close  Dept
# 0      24924.50  53.450001     1
# 1      50605.27  53.450001     2
# 2      13740.12  53.450001     3
# 3      39954.04  53.450001     4
# 4      32229.38  53.450001     5

# %%
#Replace Close price using backfill methid
df_features_train_stock['Close'].fillna(method = 'bfill', inplace = True)

# %%
#Replace Unemployment with the mean
df_features_train_stock['Unemployment'].fillna(df_features_train_stock['Unemployment'].mean(), inplace = True)

# %%
# Fill CPA values with the mean
df_features_train_stock['CPI'].fillna(df_features_train_stock['CPI'].mean(), inplace = True)

# %%
df_features_train_stock.dropna()
# Out:
#              Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0      2010-02-05        42.31       2.572  211.096358         8.106
# 1      2010-02-05        42.31       2.572  211.096358         8.106
# 2      2010-02-05        42.31       2.572  211.096358         8.106
# 3      2010-02-05        42.31       2.572  211.096358         8.106
# 4      2010-02-05        42.31       2.572  211.096358         8.106
# ...           ...          ...         ...         ...           ...
# 409722 2012-10-26        58.85       3.882  192.308899         8.667
# 409723 2012-10-26        58.85       3.882  192.308899         8.667
# 409724 2012-10-26        58.85       3.882  192.308899         8.667
# 409725 2012-10-26        58.85       3.882  192.308899         8.667
# 409726 2012-10-26        58.85       3.882  192.308899         8.667
#
#         IsHoliday  Weekly_Sales      Close  Dept
# 0           False      24924.50  53.450001     1
# ...

# %%
#Save the columns names
columns_list = df_features_train_stock.columns

# %%
columns_list
# Out:
# Index(['Date', 'Temperature', 'Fuel_Price', 'CPI', 'Unemployment', 'IsHoliday',
#        'Weekly_Sales', 'Close', 'Dept'],
#       dtype='object')

# %% [markdown]
# # Group the data frame to have it more readable and easier to work on

# %%
'''We saw the date columm for some reason during the merge, it has repetition on the values, therefore we are able to
group the data in dates. In addition, since all values are repetions, we are also able to aggregate them as mean
and final results would be summarized and not affected'''
# Out:
# 'We saw the date columm for some reason during the merge, it has repetition on the values, therefore we are able to\ngroup the data in dates. In addition, since all values are repetions, we are also able to aggregate them as mean\nand final results would be summarized and not affected'

# %%
df_walmart = df_features_train_stock.groupby('Date').agg({'Temperature':'mean', 'Fuel_Price':'mean', 
                                                                  'CPI':'mean', 'Unemployment':'mean', 
                                                                  'IsHoliday':'mean','Weekly_Sales':'sum',
                                                                  'Close':'mean'})

# %%
df_walmart.head()
# Out:
#             Temperature  Fuel_Price         CPI  Unemployment  IsHoliday  \
# Date
# 2010-02-05    33.277942    2.717869  167.398405      8.576731      False
# 2010-02-12    33.361810    2.696102  167.384138      8.567309       True
# 2010-02-19    37.038310    2.673666  167.338966      8.576351      False
# 2010-02-26    38.629563    2.685642  167.691019      8.561375      False
# 2010-03-05    42.373998    2.731816  167.727351      8.572689      False
#
#             Weekly_Sales      Close
# Date
# 2010-02-05   49750740.50  53.450001
# 2010-02-12   48336677.63  52.900002
# 2010-02-19   48276993.78  53.490002
# 2010-02-26   43968571.13  54.070000
# 2010-03-05   46871470.30  54.139999

# %%
df_walmart.tail()
# Out:
#             Temperature  Fuel_Price         CPI  Unemployment  IsHoliday  \
# Date
# 2012-09-28    68.151759    3.858245  175.919639      7.225855      False
# 2012-10-05    65.456811    3.848435  175.998254      6.942141      False
# 2012-10-12    57.687284    3.897425  176.123786      6.952682      False
# 2012-10-19    60.152756    3.878413  176.295499      6.948928      False
# 2012-10-26    60.530277    3.791086  176.182886      6.943212      False
#
#             Weekly_Sales      Close
# Date
# 2012-09-28   43734899.40  73.800003
# 2012-10-05   47566639.31  75.129997
# 2012-10-12   46128514.25  75.809998
# 2012-10-19   45122410.57  75.620003
# 2012-10-26   45544116.29  75.110001

# %%
#Double check the types of the columns of our main data frame and everything looks good.
df_walmart.dtypes
# Out:
# Temperature     float64
# Fuel_Price      float64
# CPI             float64
# Unemployment    float64
# IsHoliday          bool
# Weekly_Sales    float64
# Close           float64
# dtype: object

# %%
#Make a list of the column names
column_names_df = df_walmart.columns

# %%
#Print the unique values of the dataframe to see any anomalies
def unique_values():
    for i in column_names_df:
        print(i)
        print(df_walmart[i].unique())

# %%
unique_values()
# Out:
# Temperature
# [33.27794247 33.36180988 37.03831038 38.62956286 42.37399796 46.96714286
#  49.48101937 47.97932474 58.09852592 57.49340014 56.52116945 57.28949658
#  63.81698158 59.90745722 65.68981106 70.15721018 73.01480069 73.93617051
#  73.08862906 78.32468975 76.55595475 78.57755081 79.95275422 80.6986726
#  78.81814535 79.55248968 79.05798688 78.97084454 76.21682885 76.06353383
#  71.9292271  70.67358143 70.54389836 69.3869983  61.2752282  60.3151843
#  58.53009543 58.71418145 52.04093857 49.87114413 47.6941358  47.33594622
#  41.19615124 38.40845997 39.56289625 36.08826368 34.79524232 29.99595287
#  36.69935915 33.25839329 29.80758373 31.44570456 45.21960611 42.34485334
#  43.98275524 46.45343455 52.36840624 50.97975527 47.94236191 55.05583305
#  56.60845242 61.69543699 57.69305649 64.57785642 61.97390668 69.11696908
#  73.12914784 74.4125513  74.27129711 75.70794679 78.20163425 79.5448277
#  79.57782148 81.88677298 80.8229976  80.94234551 80.01752729 78.6946529
# ...

# %%
#By looking at the unique values, everything looks good

# %% [markdown]
# # Final data frame

# %%
pd.set_option('Max_rows', None)
df_walmart
# Out:
#             Temperature  Fuel_Price         CPI  Unemployment  IsHoliday  \
# Date
# 2010-02-05    33.277942    2.717869  167.398405      8.576731      False
# 2010-02-12    33.361810    2.696102  167.384138      8.567309       True
# 2010-02-19    37.038310    2.673666  167.338966      8.576351      False
# 2010-02-26    38.629563    2.685642  167.691019      8.561375      False
# 2010-03-05    42.373998    2.731816  167.727351      8.572689      False
# 2010-03-12    46.967143    2.774452  167.504162      8.580858      False
# 2010-03-19    49.481019    2.816063  167.478101      8.571996      False
# 2010-03-26    47.979325    2.823610  167.510338      8.575041      False
# 2010-04-09    58.098526    2.852423  167.265977      8.442531      False
# 2010-04-16    57.493400    2.887358  167.236170      8.451255      False
# 2010-04-23    56.521169    2.881633  167.065968      8.449770      False
# 2010-04-30    57.289497    2.891414  167.192558      8.448838      False
# ...
